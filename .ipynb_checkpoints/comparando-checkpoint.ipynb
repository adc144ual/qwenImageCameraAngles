# %%
import cv2
import mediapipe as mp
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass

@dataclass
class Landmark:
    x: float
    y: float
    landmark_id: int = None

# Definimos las conexiones de MediaPipe
mp_holistic = mp.solutions.holistic
POSE_CONNECTIONS = mp_holistic.POSE_CONNECTIONS
HAND_CONNECTIONS = mp_holistic.HAND_CONNECTIONS

def get_landmarks_from_image(image_path):

    with mp_holistic.Holistic(static_image_mode=True, min_detection_confidence=0.5) as holistic:

        image = cv2.imread(image_path)

        if image is None: 

            print("No hay foto crack")

            return None, None

        

        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        results = holistic.process(image_rgb)

        

        all_lms = {}

        if results.pose_landmarks:

            all_lms["pose"] = [Landmark(lm.x, lm.y, i) for i, lm in enumerate(results.pose_landmarks.landmark)]

        if results.left_hand_landmarks:

            all_lms["left_hand"] = [Landmark(lm.x, lm.y) for lm in results.left_hand_landmarks.landmark]

        if results.right_hand_landmarks:

            all_lms["right_hand"] = [Landmark(lm.x, lm.y) for lm in results.right_hand_landmarks.landmark]

            

        return all_lms, image_rgb



def normalize_landmarks(landmarks, tam_target=100, margin=5):

    """

    Escala todos los puntos para que el cuerpo completo ocupe el máximo 

    espacio posible dentro del canvas, manteniendo la proporción.

    """

    # 1. Reunir todos los puntos (pose y manos) para calcular límites globales

    all_points = []

    for key in landmarks:

        all_points.extend(landmarks[key])

    

    if not all_points:

        return landmarks



    # 2. Encontrar extremos (Bounding Box)

    min_x = min(lm.x for lm in all_points)

    max_x = max(lm.x for lm in all_points)

    min_y = min(lm.y for lm in all_points)

    max_y = max(lm.y for lm in all_points)



    width = max_x - min_x

    height = max_y - min_y

    

    # Evitar división por cero

    if width == 0: width = 0.01

    if height == 0: height = 0.01



    # 3. Calcular escala manteniendo la relación de aspecto

    # Queremos que la dimensión más grande ocupe (tam_target - 2*margin)

    available_space = tam_target - (2 * margin)

    scale = available_space / max(width, height)



    # 4. Calcular desplazamientos para centrar el cuerpo

    # Centramos el contenido dentro del margen

    offset_x = margin + (available_space - width * scale) / 2

    offset_y = margin + (available_space - height * scale) / 2



    def transform(lm):

        # Normalizamos: (punto - min) escala el objeto a 0..X, luego sumamos el offset

        new_x = (lm.x - min_x) * scale + offset_x

        new_y = (lm.y - min_y) * scale + offset_y

        return Landmark(x=new_x, y=new_y, landmark_id=lm.landmark_id)



    normalized_data = {}

    for k, list_lms in landmarks.items():

        normalized_data[k] = [transform(lm) for lm in list_lms]

    return normalized_data



def plot_landmarks(landmarks, background_img=None, tam=512, is_normalized=True):

    # Usamos tam=512 por defecto para que la imagen final sea nítida

    if background_img is not None:

        img = background_img.copy()

    else:

        img = np.zeros((tam, tam, 3), dtype=np.uint8)

    

    h, w = img.shape[:2]



    def to_pixel(point):

        if is_normalized:

            # point.x está en rango 0-100

            return (int(point.x * w / 100), int(point.y * h / 100))

        return (int(point.x * w), int(point.y * h))



    # Dibujar conexiones

    lines = [("pose", POSE_CONNECTIONS), ("left_hand", HAND_CONNECTIONS), ("right_hand", HAND_CONNECTIONS)]

    for key, connections in lines:

        if key in landmarks:

            lms = landmarks[key]

            for start_idx, end_idx in connections:

                if start_idx < len(lms) and end_idx < len(lms):

                    cv2.line(img, to_pixel(lms[start_idx]), to_pixel(lms[end_idx]), (255, 255, 255), 2)



    # Dibujar puntos

    for p in landmarks.get("pose", []):

        cv2.circle(img, to_pixel(p), 4, (0, 0, 255), -1)

    for hand in ["left_hand", "right_hand"]:

        for p in landmarks.get(hand, []):

            cv2.circle(img, to_pixel(p), 3, (255, 0, 0), -1)



    return img

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from tqdm import tqdm

# --- Tus funciones base (get_landmarks_from_image, normalize_landmarks, plot_landmarks) ---
# [Asume que aquí van las funciones que proporcionaste en tu primer mensaje]

def get_timestamp(filename):
    """Extrae el timestamp numérico del nombre del archivo."""
    # Ejemplo: 00_16_1680259461010_rgb.png -> 1680259461010
    parts = filename.split('_')
    for p in parts:
        if p.isdigit() and len(p) > 10:
            return p
    return None

def compute_metrics(lms_ref, lms_gen, mode="points"):
    """
    Calcula la diferencia entre dos conjuntos de landmarks.
    mode: "points" (Distancia Euclídea) o "pixels" (MSE de imágenes)
    """
    if not lms_ref or not lms_gen:
        return None

    # Solo comparamos las claves que existan en ambos (usualmente 'pose')
    common_keys = set(lms_ref.keys()) & set(lms_gen.keys())
    if not common_keys: return None

    if mode == "points":
        distances = []
        for k in common_keys:
            # Comparamos punto a punto
            for p1, p2 in zip(lms_ref[k], lms_gen[k]):
                dist = np.sqrt((p1.x - p2.x)**2 + (p1.y - p2.y)**2)
                distances.append(dist)
        return np.mean(distances) if distances else None

    elif mode == "pixels":
        # Generamos imágenes 100x100 para restar
        img_ref = plot_landmarks(lms_ref, tam=100, is_normalized=True)
        img_gen = plot_landmarks(lms_gen, tam=100, is_normalized=True)
        # Convertir a escala de grises para el error
        gray_ref = cv2.cvtColor(img_ref, cv2.COLOR_RGB2GRAY)
        gray_gen = cv2.cvtColor(img_gen, cv2.COLOR_RGB2GRAY)
        mse = np.mean((gray_ref.astype(float) - gray_gen.astype(float))**2)
        return mse

def run_study(base_path, target_views=["00_15", "00_16"], mode="points", limit=100):
    results = []
    comparisons_for_plot = []
    
    path_test = os.path.join(base_path, "test")
    path_gen_root = os.path.join(base_path, "00_17")

    for view in target_views:
        print(f"--- Analizando Vista {view} (Modo: {mode}) ---")
        real_dir = os.path.join(path_test, view)
        fake_dir = os.path.join(path_gen_root, f"to_{view}")
        
        # Mapear archivos reales por timestamp
        real_files = {get_timestamp(f): f for f in os.listdir(real_dir) if f.endswith(('.png', '.jpg'))}
        fake_files = os.listdir(fake_dir)
        
        count = 0
        for f_fake in tqdm(fake_files):
            if count >= limit: break
            
            ts = get_timestamp(f_fake)
            if ts in real_files:
                # 1. Extraer poses
                lms_fake, _ = get_landmarks_from_image(os.path.join(fake_dir, f_fake))
                lms_real, _ = get_landmarks_from_image(os.path.join(real_dir, real_files[ts]))
                
                if lms_fake and lms_real:
                    # 2. Normalizar
                    norm_fake = normalize_landmarks(lms_fake)
                    norm_real = normalize_landmarks(lms_real)
                    
                    # 3. Calcular Métrica
                    error = compute_metrics(norm_real, norm_fake, mode=mode)
                    
                    if error is not None:
                        results.append({
                            'view': view,
                            'timestamp': ts,
                            'error': error,
                            'mode': mode
                        })
                        # Guardar para el collage final
                        comparisons_for_plot.append((norm_real, norm_fake, view, ts))
                        count += 1

    # Guardar CSV
    df = pd.DataFrame(results)
    df.to_csv(f"estudio_pose_{mode}_{limit}_imgs.csv", index=False)
    
    # Generar Gráfica de Errores
    plt.figure(figsize=(10, 6))
    for view in target_views:
        subset = df[df['view'] == view]
        plt.hist(subset['error'], bins=20, alpha=0.5, label=f'Error en {view}')
    
    plt.title(f"Distribución del Error de Pose (Modo: {mode})")
    plt.xlabel("Error" if mode=="pixels" else "Distancia Euclídea Media (%)")
    plt.ylabel("Frecuencia")
    plt.legend()
    plt.savefig(f"grafica_error_{mode}.png")
    
    # Generar ejemplos visuales aleatorios
    generate_collage(comparisons_for_plot, mode)
    
    return df

def generate_collage(comparisons, mode, n_samples=3):
    samples = random.sample(comparisons, min(n_samples, len(comparisons)))
    fig, axes = plt.subplots(len(samples), 2, figsize=(10, 5 * len(samples)))
    
    for i, (real, fake, view, ts) in enumerate(samples):
        img_real = plot_landmarks(real, tam=256, is_normalized=True)
        img_fake = plot_landmarks(fake, tam=256, is_normalized=True)
        
        axes[i, 0].imshow(img_real)
        axes[i, 0].set_title(f"REAL - Vista {view} ({ts})")
        axes[i, 1].imshow(img_fake)
        axes[i, 1].set_title(f"SINTÉTICA - Vista {view}")
        
    plt.tight_layout()
    plt.savefig(f"ejemplos_comparacion_{mode}.png")
    print(f"Proceso finalizado. Resultados guardados en estudio_pose_{mode}.csv y gráficas generadas.")

# --- EJECUCIÓN ---
BASE_PATH = "/nas/antoniodetoro/qwen/Qwen-Image-Edit-Angles-2/MultiViewVisibleImagesHPE_100"
# Cambia mode="points" por mode="pixels" según necesites
df_results = run_study(BASE_PATH, mode="points", limit=10)
# Out:
# --- Analizando Vista 00_15 (Modo: points) ---
#   0%|          | 0/101 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769511707.145981 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511707.227281 1240676 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1769511707.297049 1240598 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.332453 1240618 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.334374 1240596 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.334603 1240601 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.337050 1240630 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.344594 1240631 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.353250 1240599 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.353599 1240635 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# W0000 00:00:1769511707.356943 1240603 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511707.414489 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511707.465994 1240854 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511707.519560 1240794 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.568533 1240807 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.573591 1240811 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.574196 1240805 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.575750 1240827 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.595012 1240844 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.608709 1240832 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.609205 1240819 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   1%|          | 1/101 [00:00<00:58,  1.70it/s]I0000 00:00:1769511707.695806 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511707.743748 1240919 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511707.792096 1240859 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.844360 1240870 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.846453 1240860 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.846767 1240856 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.848606 1240884 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.852081 1240901 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.860004 1240896 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511707.884026 1240911 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511707.967696 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511708.019600 1240984 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511708.072514 1240921 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.121247 1240932 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.128446 1240981 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.128852 1240978 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.129165 1240974 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.137802 1240966 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.139001 1240959 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.154692 1240975 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|▏         | 2/101 [00:01<00:56,  1.75it/s]I0000 00:00:1769511708.237710 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511708.319010 1241049 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511708.368150 1240987 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708.419900 1241002 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511708
inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.073647 1243220 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.076240 1243237 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.076445 1243239 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.077847 1243220 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.080037 1243243 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.098549 1243252 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.101082 1243255 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   8%|▊         | 8/101 [00:04<00:51,  1.80it/s]I0000 00:00:1769511717.200970 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511717.253072 1243338 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511717.306316 1243276 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.364377 1243288 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.366316 1243303 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.366548 1243305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.367576 1243288 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.375119 1243315 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.378474 1243277 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.394610 1243310 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511717.486496 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511717.538296 1243403 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511717.581793 1243339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.632711 1243355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.634754 1243351 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.634975 1243349 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.634978 1243350 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.639951 1243391 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.641186 1243385 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.643242 1243378 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   9%|▉         | 9/101 [00:05<00:50,  1.82it/s]I0000 00:00:1769511717.714674 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511717.762383 1243514 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511717.818809 1243448 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.857781 1243464 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.859691 1243449 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.859845 1243482 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.859848 1243471 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.864400 1243491 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.874088 1243479 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511717.874465 1243496 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511717.942454 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511717.990990 1243598 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511718.048850 1243539 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511718.100034 1243554 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511718.102093 1243537 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511718.102232 1243597 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511718.102914 1243561 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511718.115454 1243593 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511718.117445 1243573 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511718.133042 1243542 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  10%|▉         | 10/101 [00:05<00:50,  1.79it/s]
# Proceso finalizado. Resultados guardados en estudio_pose_points.csv y gráficas generadas.

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from tqdm import tqdm

# --- Tus funciones base (get_landmarks_from_image, normalize_landmarks, plot_landmarks) ---
# [Asume que aquí van las funciones que proporcionaste en tu primer mensaje]

def get_timestamp(filename):
    """Extrae el timestamp numérico del nombre del archivo."""
    # Ejemplo: 00_16_1680259461010_rgb.png -> 1680259461010
    parts = filename.split('_')
    for p in parts:
        if p.isdigit() and len(p) > 10:
            return p
    return None

def compute_metrics(lms_ref, lms_gen, mode="points"):
    """
    Calcula la diferencia entre dos conjuntos de landmarks.
    mode: "points" (Distancia Euclídea) o "pixels" (MSE de imágenes)
    """
    if not lms_ref or not lms_gen:
        return None

    # Solo comparamos las claves que existan en ambos (usualmente 'pose')
    common_keys = set(lms_ref.keys()) & set(lms_gen.keys())
    if not common_keys: return None

    if mode == "points":
        distances = []
        for k in common_keys:
            # Comparamos punto a punto
            for p1, p2 in zip(lms_ref[k], lms_gen[k]):
                dist = np.sqrt((p1.x - p2.x)**2 + (p1.y - p2.y)**2)
                distances.append(dist)
        return np.mean(distances) if distances else None

    elif mode == "pixels":
        # Generamos imágenes 100x100 para restar
        img_ref = plot_landmarks(lms_ref, tam=100, is_normalized=True)
        img_gen = plot_landmarks(lms_gen, tam=100, is_normalized=True)
        # Convertir a escala de grises para el error
        gray_ref = cv2.cvtColor(img_ref, cv2.COLOR_RGB2GRAY)
        gray_gen = cv2.cvtColor(img_gen, cv2.COLOR_RGB2GRAY)
        mse = np.mean((gray_ref.astype(float) - gray_gen.astype(float))**2)
        return mse

def run_study(base_path, target_views=["00_15", "00_16"], mode="points", limit=100):
    results = []
    comparisons_for_plot = []
    
    path_test = os.path.join(base_path, "test")
    path_gen_root = os.path.join(base_path, "00_17")

    for view in target_views:
        print(f"--- Analizando Vista {view} (Modo: {mode}) ---")
        real_dir = os.path.join(path_test, view)
        fake_dir = os.path.join(path_gen_root, f"to_{view}")
        
        # Mapear archivos reales por timestamp
        real_files = {get_timestamp(f): f for f in os.listdir(real_dir) if f.endswith(('.png', '.jpg'))}
        fake_files = os.listdir(fake_dir)
        
        count = 0
        for f_fake in tqdm(fake_files):
            if count >= limit: break
            
            ts = get_timestamp(f_fake)
            if ts in real_files:
                # 1. Extraer poses
                lms_fake, _ = get_landmarks_from_image(os.path.join(fake_dir, f_fake))
                lms_real, _ = get_landmarks_from_image(os.path.join(real_dir, real_files[ts]))
                
                if lms_fake and lms_real:
                    # 2. Normalizar
                    norm_fake = normalize_landmarks(lms_fake)
                    norm_real = normalize_landmarks(lms_real)
                    
                    # 3. Calcular Métrica
                    error = compute_metrics(norm_real, norm_fake, mode=mode)
                    
                    if error is not None:
                        results.append({
                            'view': view,
                            'timestamp': ts,
                            'error': error,
                            'mode': mode
                        })
                        # Guardar para el collage final
                        comparisons_for_plot.append((norm_real, norm_fake, view, ts))
                        count += 1

    # Guardar CSV
    df = pd.DataFrame(results)
    df.to_csv(f"estudio_pose_{mode}_{limit}_imgs.csv", index=False)
    
    # Generar Gráfica de Errores
    plt.figure(figsize=(10, 6))
    for view in target_views:
        subset = df[df['view'] == view]
        plt.hist(subset['error'], bins=20, alpha=0.5, label=f'Error en {view}')
    
    plt.title(f"Distribución del Error de Pose (Modo: {mode})")
    plt.xlabel("Error" if mode=="pixels" else "Distancia Euclídea Media (%)")
    plt.ylabel("Frecuencia")
    plt.legend()
    plt.savefig(f"grafica_error_{mode}.png")
    
    # Generar ejemplos visuales aleatorios
    generate_collage(comparisons_for_plot, mode)
    
    return df

def generate_collage(comparisons, mode, n_samples=3):
    samples = random.sample(comparisons, min(n_samples, len(comparisons)))
    fig, axes = plt.subplots(len(samples), 2, figsize=(10, 5 * len(samples)))
    
    for i, (real, fake, view, ts) in enumerate(samples):
        img_real = plot_landmarks(real, tam=256, is_normalized=True)
        img_fake = plot_landmarks(fake, tam=256, is_normalized=True)
        
        axes[i, 0].imshow(img_real)
        axes[i, 0].set_title(f"REAL - Vista {view} ({ts})")
        axes[i, 1].imshow(img_fake)
        axes[i, 1].set_title(f"SINTÉTICA - Vista {view}")
        
    plt.tight_layout()
    plt.savefig(f"ejemplos_comparacion_{mode}.png")
    print(f"Proceso finalizado. Resultados guardados en estudio_pose_{mode}.csv y gráficas generadas.")

# --- EJECUCIÓN ---
BASE_PATH = "/nas/antoniodetoro/qwen/Qwen-Image-Edit-Angles-2/MultiViewVisibleImagesHPE_100"
# Cambia mode="points" por mode="pixels" según necesites
df_results = run_study(BASE_PATH, mode="pixels", limit=10)
# Out:
# --- Analizando Vista 00_15 (Modo: pixels) ---
#   0%|          | 0/101 [00:00<?, ?it/s]I0000 00:00:1769511806.259142 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511806.314117 1245970 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511806.359706 1245908 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.409377 1245923 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.411625 1245911 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.411639 1245969 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.411823 1245967 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.417410 1245953 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.431206 1245969 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.432937 1245967 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511806.520669 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511806.571734 1246035 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511806.633436 1245974 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.691510 1245986 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.693512 1246006 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.693702 1246005 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.694470 1245986 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806.700767 1246017 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511806
inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   6%|▌         | 6/101 [00:03<00:52,  1.81it/s]I0000 00:00:1769511815.203944 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511815.256667 1248258 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511815.323355 1248198 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.372488 1248209 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.375084 1248210 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.375363 1248229 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.375517 1248227 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.382823 1248230 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.397263 1248244 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.399381 1248239 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511815.505698 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511815.555341 1248323 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511815.631151 1248261 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.686419 1248277 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.688315 1248289 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.689127 1248287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.691293 1248262 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.693584 1248303 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.696481 1248291 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.714405 1248304 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   7%|▋         | 7/101 [00:03<00:53,  1.76it/s]I0000 00:00:1769511815.808653 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511815.859299 1248388 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511815.913687 1248326 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.949509 1248339 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.951187 1248329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.952230 1248333 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.952230 1248338 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.955149 1248368 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.956926 1248375 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511815.971111 1248355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511816.029495 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511816.077257 1248520 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511816.136443 1248458 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.183012 1248474 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.185552 1248492 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.186221 1248510 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.186253 1248509 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.190003 1248490 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.195500 1248506 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.195742 1248504 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   8%|▊         | 8/101 [00:04<00:50,  1.84it/s]I0000 00:00:1769511816.330353 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511816.378769 1248585 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511816.433369 1248522 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.474792 1248537 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.476560 1248551 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.477075 1248547 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.477752 1248537 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.483465 1248565 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.484907 1248556 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.486348 1248569 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511816.598164 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511816.646661 1248650 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511816.699376 1248587 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.735966 1248602 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.739300 1248635 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.740022 1248636 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.740584 1248642 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.748020 1248591 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.752698 1248629 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511816.756111 1248619 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   9%|▉         | 9/101 [00:05<00:50,  1.81it/s]I0000 00:00:1769511816.868483 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511816.921237 1248716 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511816.983651 1248654 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.030284 1248671 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.033290 1248696 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.033572 1248699 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.033589 1248697 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.041514 1248688 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.042871 1248701 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.056739 1248700 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1769511817.165722 1235245 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769511817.214938 1248782 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.05), renderer: NVIDIA A30/PCIe/SSE2
# W0000 00:00:1769511817.268385 1248720 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.307074 1248733 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.310085 1248747 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.310455 1248748 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.312143 1248733 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.319100 1248752 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.323062 1248757 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769511817.337258 1248764 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#  10%|▉         | 10/101 [00:05<00:50,  1.79it/s]
# Proceso finalizado. Resultados guardados en estudio_pose_pixels.csv y gráficas generadas.

# %% [markdown]
# # Búsqueda Inversa
# (Se comprueban las originales sólo de las generadas que se encuentren)

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from tqdm import tqdm

# --- [Aquí van tus funciones: get_landmarks_from_image, normalize_landmarks, plot_landmarks] ---

def get_timestamp(filename):
    """Extrae el timestamp numérico del nombre del archivo."""
    # Ejemplo: Step_6_fake_00_15_from_00_17_1680259460708_rgb -> 1680259460708
    parts = filename.split('_')
    for p in parts:
        if p.isdigit() and len(p) > 10:
            return p
    return None

def compute_metrics(lms_ref, lms_gen, mode="points"):
    if not lms_ref or not lms_gen: return None
    common_keys = set(lms_ref.keys()) & set(lms_gen.keys())
    if not common_keys: return None

    if mode == "points":
        distances = []
        for k in common_keys:
            # zip asegura que comparamos landmark 0 con landmark 0, etc.
            for p1, p2 in zip(lms_ref[k], lms_gen[k]):
                dist = np.sqrt((p1.x - p2.x)**2 + (p1.y - p2.y)**2)
                distances.append(dist)
        return np.mean(distances) if distances else None

    elif mode == "pixels":
        img_ref = plot_landmarks(lms_ref, tam=100, is_normalized=True)
        img_gen = plot_landmarks(lms_gen, tam=100, is_normalized=True)
        gray_ref = cv2.cvtColor(img_ref, cv2.COLOR_RGB2GRAY)
        gray_gen = cv2.cvtColor(img_gen, cv2.COLOR_RGB2GRAY)
        return np.mean((gray_ref.astype(float) - gray_gen.astype(float))**2)

def run_study(base_path, target_views=["00_15", "00_16"], mode="points", limit=10):
    results = []
    comparisons_for_plot = []
    
    path_test = os.path.join(base_path, "test")
    path_gen_root = os.path.join(base_path, "00_17")

    for view in target_views:
        fake_dir = os.path.join(path_gen_root, f"to_{view}")
        real_dir = os.path.join(path_test, view)
        
        if not os.path.exists(fake_dir):
            print(f"Carpeta no encontrada: {fake_dir}")
            continue

        # 1. Mapear archivos REALES por timestamp para búsqueda instantánea
        real_files_map = {get_timestamp(f): f for f in os.listdir(real_dir) if f.endswith(('.png', '.jpg'))}
        
        # 2. Iterar SOLO sobre las imágenes generadas
        fake_files = [f for f in os.listdir(fake_dir) if f.endswith(('.png', '.jpg'))]
        print(f"\n--- Procesando {len(fake_files)} imágenes generadas hacia vista {view} ---")
        
        count = 0
        for f_fake in tqdm(fake_files):
            if count >= limit: break
            
            ts = get_timestamp(f_fake)
            if ts in real_files_map:
                f_real = real_files_map[ts]
                
                # Extraer y procesar
                lms_fake, _ = get_landmarks_from_image(os.path.join(fake_dir, f_fake))
                lms_real, _ = get_landmarks_from_image(os.path.join(real_dir, f_real))
                
                if lms_fake and lms_real:
                    norm_fake = normalize_landmarks(lms_fake)
                    norm_real = normalize_landmarks(lms_real)
                    
                    error = compute_metrics(norm_real, norm_fake, mode=mode)
                    
                    if error is not None:
                        results.append({'view': view, 'ts': ts, 'error': error, 'mode': mode})
                        comparisons_for_plot.append((norm_real, norm_fake, view, ts))
                        count += 1
            else:
                # Opcional: aviso si no hay par real
                pass

    # --- Generación de Outputs ---
    df = pd.DataFrame(results)
    df.to_csv(f"analisis/resultado_estudio_{mode}.csv", index=False)
    
    # Histograma
    plt.figure(figsize=(10, 6))
    for view in target_views:
        subset = df[df['view'] == view]
        if not subset.empty:
            plt.hist(subset['error'], bins=15, alpha=0.5, label=f'Vista {view}')
    
    plt.title(f"Error de Pose: Real vs Sintética ({mode})")
    plt.xlabel("Valor del error")
    plt.ylabel("Número de imágenes")
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.savefig(f"analisis/grafica_{mode}.png")
    
    generate_collage(comparisons_for_plot, mode)
    return df
    
def generate_collage(comparisons, mode, n_samples=3):
    samples = random.sample(comparisons, min(n_samples, len(comparisons)))
    fig, axes = plt.subplots(len(samples), 2, figsize=(10, 5 * len(samples)))
    
    for i, (real, fake, view, ts) in enumerate(samples):
        img_real = plot_landmarks(real, tam=256, is_normalized=True)
        img_fake = plot_landmarks(fake, tam=256, is_normalized=True)
        
        axes[i, 0].imshow(img_real)
        axes[i, 0].set_title(f"REAL - Vista {view} ({ts})")
        axes[i, 1].imshow(img_fake)
        axes[i, 1].set_title(f"SINTÉTICA - Vista {view}")
        
    plt.tight_layout()
    plt.savefig(f"analisis/ejemplos_comparacion_{mode}.png")
    print(f"Proceso finalizado. Resultados guardados en estudio_pose_{mode}.csv y gráficas generadas.")


